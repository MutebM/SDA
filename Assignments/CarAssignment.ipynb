# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_price = pd.read_csv('Price_table.csv')
df_price.head()
# Out:
#     Maker    Genmodel Genmodel_ID  Year  Entry_price
# 0  Abarth  124 Spider         2_1  2016        29365
# 1  Abarth  124 Spider         2_1  2017        26665
# 2  Abarth  124 Spider         2_1  2018        26665
# 3  Abarth  124 Spider         2_1  2019        29515
# 4  Abarth         500         2_2  2009        13400

# %%
print("Shape:", df_price.shape)
print("\nData Types:\n", df_price.dtypes)
# Out:
# Shape: (6333, 5)
#
# Data Types:
#  Maker          object
# Genmodel       object
# Genmodel_ID    object
# Year            int64
# Entry_price     int64
# dtype: object

# %%
# Missing values
print("\nMissing Values:\n", df_price.isnull().sum())
# Out:
# Missing Values:
#  Maker          0
# Genmodel       0
# Genmodel_ID    0
# Year           0
# Entry_price    0
# dtype: int64

# %%
import pygwalker as pyg

pyg.walk(df_price)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00065343663758fa6XTqoFrSyU0dLnDp" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00065343663758fa6XTqoFrSyU0dLnDp") {
#             var iframe = document.getElementById("gwalker-00065343663758fa6XTqoFrSyU0dLnDp");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
df_sales = pd.read_csv('Sales_table.csv')
df_sales.head()
print("Shape:", df_sales.shape)
# Out:
# Shape: (773, 23)

# %%
pyg.walk(df_sales)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000653436efe310cMveIs5uoATRKbBXl" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000653436efe310cMveIs5uoATRKbBXl") {
#             var iframe = document.getElementById("gwalker-000653436efe310cMveIs5uoATRKbBXl");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
df_trim = pd.read_csv('Trim_table.csv')
df_trim.head()
print("Shape:", df_trim.shape)
# Out:
# Shape: (335562, 9)

# %%
pyg.walk(df_trim)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-0006534388e1002foEPWl9sY0RKfbxUZ" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "0006534388e1002foEPWl9sY0RKfbxUZ") {
#             var iframe = document.getElementById("gwalker-0006534388e1002foEPWl9sY0RKfbxUZ");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
df_ad = pd.read_csv('Ad_table (extra).csv')
df_ad.head()
print("Shape:", df_ad.shape)
# Out:
# Shape: (268255, 24)

# %%
df_ad.isna().sum()
# Out:
# Maker               0
#  Genmodel           0
#  Genmodel_ID        0
# Adv_ID              0
# Adv_year            0
# Adv_month           0
# Color           21875
# Reg_year            7
# Bodytype          954
# Runned_Miles     1055
# Engin_size       2064
# Gearbox           167
# Fuel_type         409
# Price            1145
# Engine_power    31811
# Annual_Tax      46675
# Wheelbase       27998
# Height          27801
# Width           28080
# Length          27801
# Average_mpg     41933
# Top_speed       43602
# Seat_num         6474
# Door_num         4553
# dtype: int64

# %%
cleaned_df_ad=df_ad.dropna()

# %%
cleaned_df_ad.isna().sum()
# Out:
# Maker           0
#  Genmodel       0
#  Genmodel_ID    0
# Adv_ID          0
# Adv_year        0
# Adv_month       0
# Color           0
# Reg_year        0
# Bodytype        0
# Runned_Miles    0
# Engin_size      0
# Gearbox         0
# Fuel_type       0
# Price           0
# Engine_power    0
# Annual_Tax      0
# Wheelbase       0
# Height          0
# Width           0
# Length          0
# Average_mpg     0
# Top_speed       0
# Seat_num        0
# Door_num        0
# dtype: int64

# %%
pyg.walk(cleaned_df_ad)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00065343a728ce3caHZCFiX13QLtmbz8" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00065343a728ce3caHZCFiX13QLtmbz8") {
#             var iframe = document.getElementById("gwalker-00065343a728ce3caHZCFiX13QLtmbz8");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
